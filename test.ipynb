# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
# %matplotlib inline

# %%
data = yf.download("NFLX",start = "2020-01-01",end= "2022-06-30")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
def z_score(chunk):
    return (chunk[-1] - chunk.mean()) / chunk.std()

# %%
rolled = data.Close.rolling(window=30).apply(z_score)
# Out:
# /var/folders/pj/_8zjbnds77bbj7nmgmph8jch0000gn/T/ipykernel_71942/1290700275.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return (chunk[-1] - chunk.mean()) / chunk.std()

# %%
rolled.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
rolled.hist(bins=20)
# Out:
# <Axes: >

# %%
min_pct_change = (
    data
    .Close
    .pct_change()
    .rolling(window=30)
    .min()
)

# %%
min_pct_change.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
min_pct_change.hist(bins=20)
# Out:
# <Axes: >
